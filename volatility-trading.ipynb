# %% [markdown]
# # Volatility Analysis
#
# Volatility analysis is a critical aspect of financial market strategies, providing insights into price fluctuations and helping traders assess risk and identify profitable opportunities. In this analysis, several volatility metrics are calculated to give a comprehensive view of asset behavior and market risk. Here's how the analysis works:
#
# - **Identifying Volatility Metrics**: A set of volatility indicators is computed to assess the magnitude and frequency of price movements. These metrics include:
#   - **Standard Deviation of Returns**: Measures the overall price variability over a set period. Higher values indicate higher volatility.
#   - **Average True Range (ATR) Relative to Price**: Measures the average range of price movement, adjusted for the closing price, with higher values indicating greater volatility.
#   - **Price Range Relative to Price**: Evaluates the average daily price movement relative to the closing price, with higher values indicating more volatile assets.
#   - **Skewness of Returns**: Indicates asymmetry in the asset's price distribution, with negative skewness suggesting the likelihood of larger downward movements.
#   - **Choppiness Index (CHOP)**: Measures how erratic the price movement is. A higher value indicates more choppy, volatile price behavior.
#   - **Cumulative Volatility**: Sums the rolling volatility over a set period, highlighting overall market fluctuation.
#   - **Logarithmic Returns Volatility**: Provides a more nuanced volatility measurement by considering the compounding of price changes over time.
#
# <!-- - **Analyzing Historical Performance**: Historical price data is analyzed to determine how the asset behaves under different market conditions. These metrics allow traders to identify periods of high and low volatility, helping in the decision-making process for risk management and trade entry/exit. -->
#
# - **Executing Trades**: By identifying assets with high volatility, traders can use this information to adjust their trading strategies. For example, increased volatility may present short-term trading opportunities, while lower volatility periods may suggest a more cautious approach. Traders might enter positions during periods of high volatility if they anticipate price movement in their favor or avoid positions during low volatility to reduce risk.
#
# - **Monitoring and Adjusting**: Volatility analysis requires continuous monitoring of asset behavior and market conditions. Traders adjust their strategies in real-time, responding to sudden volatility spikes or drops, ensuring that risk is managed appropriately.
#
# In this notebook, volatility analysis is demonstrated using historical price data from various cryptocurrency exchanges such as Binance, OKX, and Bybit. The computed metrics offer valuable insights for market participants seeking to understand asset behavior and make informed decisions in volatile markets.

# %% [markdown]
# ## Prepare your Environment
#
# Ensure that the correct kernel is selected for this notebook. If you are following the instruction in *README.md*, the kernel is 'crypto-trading-analysis'. To check, click on 'Kernel' at the top bar, select 'Change Kernel...' and select the correct kernel. For convenience, ensure that 'Always start the preferred kernel' is ticked. Click 'Select' to confirm the setting.
#
# Install the environment's dependencies using the command below. After installation, restart the kernel to use the updated packages. To restart, click on 'Kernel' at the top bar and select 'Restart Kernel' and click on 'Restart'. Please skip this step if you have already done it.

# %%
pip install -r requirements.txt

# %% [markdown]
# ## Import packages

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
import sys
from datetime import datetime
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import coint
from scipy.stats import skew
from itertools import combinations
from statsmodels.tsa.stattools import coint
from sklearn.preprocessing import MinMaxScaler
from utils import calculate_profit, plot_strategy
from data_manager import load_ts_df, process_data, sanitize_data

# %% [markdown]
# ## Process Price Dataframe
#
# - Before proceeding, ensure that the price data has been downloaded using ***'data_manager.py'***.
# - Enter the ***cex*** (Centralized Exchange) and ***interval*** values used for data download to load the relevant *.pkl* files and retrieve the dataframe.
# - You can specify a batch of pairs to load using the ***selected_pairs*** variable. If no pairs are selected, all available pairs will be loaded by default.
# - Note that some pairs might be new and may lack sufficient data within the downloaded timeframe. Such pairs will be removed based on the ***nan_remove_threshold*** setting, which defines the maximum percentage of NaN values allowed relative to the total data points. For example, with a ***nan_remove_threshold*** of 0.1, if a pair has 100 data points and 15 are NaN, the pair will be excluded.
# - From the remaining pairs, you can filter the top N volume pairs using the ***top_n_volume_pairs*** parameter.
# - This part of the code will also ensure that all timeseries columns have the same number of data points.
# - The earliest and latest dates for all pairs will be recorded. These dates can then be used to determine the timeframe for slicing the data in the next step.

# %% [markdown]
# ### Inputs

# %%
##### INPUTS #####
cex = 'binance'
interval = '1h'
nan_remove_threshold = 1

# Select only the pairs below to analyse. All pairs will be selected if the list is empty.
selected_pairs = []

# Select only the top N mean volume pairs from the selected pairs to analyse.
top_n_volume_pairs = 100

# Select volume filter mode. Options: ['rolling', 'mean'].
volume_filter_mode = 'rolling'
##################

# %%
print("\nMode: Volatility Strategy")
print("CEX: {}".format(str(cex).capitalize()))
print("Interval: {}".format(interval))
print("NaN Remove Threshold: {}".format(nan_remove_threshold))
print("Selected pairs to analyse: {}".format(selected_pairs))
print("Top N Volume Pairs: {}".format(top_n_volume_pairs))
print("Volume Filter Mode: {}".format(str(volume_filter_mode).capitalize()))

merged_df = process_data('volatility', cex, interval, nan_remove_threshold, selected_pairs,
                 top_n_volume_pairs, volume_filter_mode)

print("\n")
# Out:
# Mode: Volatility Strategy
# CEX: Binance
# Interval: 1h
# NaN Remove Threshold: 1
# Selected pairs to analyse: []
# Top N Volume Pairs: 100
# Volume Filter Mode: Rolling
#
# Columns that contains NaN values:
#                  Pair  NaN Count          Remark
# 16       BERAUSDT_Low        662  To Interpolate
# 15      BERAUSDT_High        662  To Interpolate
# 17     BERAUSDT_Close        662  To Interpolate
# 26      VVVUSDT_Close        463  To Interpolate
# 25        VVVUSDT_Low        463  To Interpolate
# 24       VVVUSDT_High        463  To Interpolate
# 9     PIPPINUSDT_High        345  To Interpolate
# 11   PIPPINUSDT_Close        345  To Interpolate
# 10     PIPPINUSDT_Low        345  To Interpolate
# 8      VINEUSDT_Close        345  To Interpolate
# 7        VINEUSDT_Low        345  To Interpolate
# 6       VINEUSDT_High        345  To Interpolate
# 1       ANIMEUSDT_Low        328  To Interpolate
# 2     ANIMEUSDT_Close        328  To Interpolate
# 0      ANIMEUSDT_High        328  To Interpolate
# 20     VTHOUSDT_Close        296  To Interpolate
# 18      VTHOUSDT_High        296  To Interpolate
# 19       VTHOUSDT_Low        296  To Interpolate
# 28    MELANIAUSDT_Low        248  To Interpolate
# 29  MELANIAUSDT_Close        248  To Interpolate
# 27   MELANIAUSDT_High        248  To Interpolate
# 35    TRUMPUSDT_Close        204  To Interpolate
# 34      TRUMPUSDT_Low        204  To Interpolate
# 33     TRUMPUSDT_High        204  To Interpolate
# 13        ARCUSDT_Low        180  To Interpolate
# 32    AVAAIUSDT_Close        180  To Interpolate
# 31      AVAAIUSDT_Low        180  To Interpolate
# 30     AVAAIUSDT_High        180  To Interpolate
# 14      ARCUSDT_Close        180  To Interpolate
# 12       ARCUSDT_High        180  To Interpolate
# 3       SOLVUSDT_High        179  To Interpolate
# 4        SOLVUSDT_Low        179  To Interpolate
# 5      SOLVUSDT_Close        179  To Interpolate
# 23        SUSDT_Close        153  To Interpolate
# 22          SUSDT_Low        153  To Interpolate
# 21         SUSDT_High        153  To Interpolate
# 36      PROMUSDT_High        131  To Interpolate
# 37       PROMUSDT_Low        131  To Interpolate
# 38     PROMUSDT_Close        131  To Interpolate
#
# Removed 0 pairs as they contain too many NaN values.
# Successfully loaded candlestick dataframe for all available pairs.
#
# Earliest time series start date: 2025-01-10
# Latest time series end date: 2025-02-09

# %% [markdown]
# ## Sanitize the dataframe
#
# - Slice the dataframe according to the specified ***start_date*** and ***end_date***. Choose ***start_date*** and ***end_date*** within the timeframe shown by the output of the previous cell.
# - Interpolate any missing values in the dataframe.
# - If the interpolation fails, just backfill with the latest valid value.
# - Verify that all is as expected with an `assert` and check the shapes of 2 random pairs, which should have the same dimensions.

# %% [markdown]
# ### Inputs

# %%
##### INPUTS #####
start_date = '2025-02-01'
end_date = '2025-02-09'
##################

# %%
print("\n")

data_sanitized, sorted_available_pairs = sanitize_data(merged_df, start_date, end_date, is_volatility_strategy=True)

if data_sanitized:
    print("-Data Check-")
    keys = list(data_sanitized.keys())
    count = 0

    for key in keys:
        print("{}'s Data Shape: {}".format(key, data_sanitized[key].shape))
        count+=1

        if count == 2:
            break
            
else:
    print("No data found.")

print("\n")
# Out:
# -Data Check-
# 1000BONKUSDT's Data Shape: (193, 3)
# 1000FLOKIUSDT's Data Shape: (193, 3)

# %% [markdown]
# ## Volatility Metrics Calculation
#
# This function calculates several volatility metrics used to assess the risk and fluctuation of asset prices over time. These metrics are commonly used in financial analysis and trading strategies to identify periods of high and low volatility.
#
# 1. **Standard Deviation of Returns**
#    The standard deviation of returns quantifies the variability of asset returns. A higher value indicates greater volatility in the asset's price movement. It is calculated as the standard deviation of the daily percentage change in the asset's closing price.
#
#    $$ \sigma_{\text{returns}} = \sqrt{\frac{1}{n-1} \sum_{i=1}^{n} (R_i - \bar{R})^2} $$
#    where:
#    - $R_i$ represents the return on day $i$,
#    - $\bar{R}$ is the mean return over the period.
#
# 2. **Average True Range (ATR) Relative to Price**
#    ATR measures market volatility by considering the largest price movement over a period, including gaps. The ATR is calculated for a 14-day window, and the relative value to the closing price is computed to normalize volatility across different price levels. Higher ATR values indicate greater volatility.
#
#    $$ \text{ATR/Price} = \frac{\text{ATR}}{\text{Close}} \times 100 $$
#
# 3. **Coin's Daily Price Range Relative to Price**
#    This metric calculates the average difference between the daily high and low prices, normalized by the closing price. Higher values indicate larger daily fluctuations, suggesting greater volatility.
#
#    $$ \text{Price Range/Price} = \frac{\text{Average High-Low Range}}{\text{Close}} \times 100 $$
#
# 4. **Skewness of Returns**
#     High Negative Skewness: Implies higher risk and higher potential volatility, as the asset could experience large downward moves. The occurrence of extreme losses could drive volatility up in the long run, even if the asset has relatively stable daily movements.
#
#     High Positive Skewness: Implies lower volatility in the short term, as the asset might experience fewer extreme losses, with larger upside moves. However, the asset's price behavior might still be volatile due to potential large upward price changes.
#
#     Skewness as a Risk Indicator: A negative skew often signals an asset with asymmetric risks—i.e., the potential for significant downside risk compared to the likelihood of large upside movements. It is useful for understanding the tail risks that could cause sharp drops in price.
#
# 5. **Choppiness Index (CHOP)**
#    The Choppiness Index measures how much the price is fluctuating (choppy) over a given period, with higher values indicating more erratic price movement, which is indicative of volatility. It compares the sum of the high-low ranges over a 14-day window to the overall maximum price range during the period.
#
#    $$ \text{CHOP} = 100 \times \frac{\sum_{i=1}^{14} (H_i - L_i)}{\text{Max Range}} $$
#    where $H_i$ and $L_i$ are the high and low prices for the window, and Max Range is the highest difference between the maximum high and minimum low over the period.
#
# 6. **Cumulative Volatility**
#    This metric sums the rolling standard deviation of returns over a 30-day period, providing a cumulative measure of volatility. A higher value signifies higher total price fluctuation over the period.
#
# 7. **Logarithmic Returns Volatility**
#    Logarithmic returns are used for calculating volatility as they account for compounding over time. The standard deviation of the log returns over a period is used as a volatility measure, where higher values indicate higher volatility.
#
#    $$ \text{Log Return} = \log\left(\frac{\text{Close}_t}{\text{Close}_{t-1}}\right) $$
#    where $\log$ denotes the natural logarithm.
#
# By combining these volatility metrics, traders can get a clearer picture of market dynamics and asset behavior, allowing them to make informed decisions about risk management and strategy optimization.

# %% [markdown]
# ### Inputs

# %%
##### INPUTS #####
window_length = 7*24 # 1 week
##################

# %%
def calculate_volatility_metrics(df, window_length):
    # Standard Deviation of Returns
    df['Return'] = df['Close'].pct_change()
    volatility_std = df['Return'].std()

    # Average True Range (ATR) Relative to Price (ATR/Price)
    df['HL'] = df['High'] - df['Low']
    df['HC'] = abs(df['High'] - df['Close'].shift(1))
    df['LC'] = abs(df['Low'] - df['Close'].shift(1))
    df['True Range'] = df[['HL', 'HC', 'LC']].max(axis=1)
    atr = df['True Range'].rolling(window=window_length).mean()
    atr_relative_to_price = (atr / df['Close']) * 100
    atr_relative_to_price = atr_relative_to_price.iloc[-1]

    # Coin's Daily Price Range Relative to Price (Price Range/Price)
    price_range = (df['High'] - df['Low']).mean()
    price_range_relative_to_price = (price_range / df['Close'].iloc[-1]) * 100

    # Skewness of Returns
    returns_skewness = skew(df['Return'].dropna())

    # Choppiness Index (CHOP)
    hl_range = df['High'] - df['Low']
    max_range = df['High'].max() - df['Low'].min()
    chop = 100 * (hl_range.rolling(window=window_length).sum() / max_range).iloc[-1]

    # Cumulative Volatility
    cum_volatility = df['Return'].rolling(window=window_length).std().sum()

    # Logarithmic Returns Volatility
    df['Log Return'] = np.log(df['Close'] / df['Close'].shift(1))
    log_volatility = df['Log Return'].std()

    return {
        'Standard Deviation (Higher = More Volatile)': volatility_std,
        'ATR/Price (Higher = More Volatile)': atr_relative_to_price,
        'Cumulative Volatility (Higher = More Volatile)': cum_volatility,
        'Logarithmic Returns Volatility (Higher = More Volatile)': log_volatility,
        'CHOP (Higher = More Choppy/Volatile)': chop,
        'Price Range/Price (Higher = More Volatile)': price_range_relative_to_price,
        'Skewness (Lower = More Volatile)': returns_skewness,
    }

volatility_metrics = {}

for coin, df in data_sanitized.items():
    metrics = calculate_volatility_metrics(df, window_length)
    volatility_metrics[coin] = metrics

volatility_df = pd.DataFrame(volatility_metrics).T  # Transpose to have coins as rows
styled_df = volatility_df.style.background_gradient(cmap="coolwarm", axis=0)

styled_df
# Out:
# <style type="text/css">
# #T_ee78a_row0_col0, #T_ee78a_row2_col6, #T_ee78a_row5_col2, #T_ee78a_row42_col3, #T_ee78a_row49_col6, #T_ee78a_row86_col6, #T_ee78a_row89_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ee78a_row0_col1, #T_ee78a_row0_col5, #T_ee78a_row1_col1, #T_ee78a_row1_col5, #T_ee78a_row5_col1, #T_ee78a_row8_col1, #T_ee78a_row12_col1, #T_ee78a_row14_col1, #T_ee78a_row22_col4, #T_ee78a_row25_col6, #T_ee78a_row32_col1, #T_ee78a_row32_col5, #T_ee78a_row35_col1, #T_ee78a_row37_col4, #T_ee78a_row39_col4, #T_ee78a_row41_col5, #T_ee78a_row48_col5, #T_ee78a_row50_col5, #T_ee78a_row51_col1, #T_ee78a_row64_col1, #T_ee78a_row73_col5, #T_ee78a_row74_col4, #T_ee78a_row77_col1, #T_ee78a_row77_col4, #T_ee78a_row84_col5, #T_ee78a_row85_col4, #T_ee78a_row97_col5, #T_ee78a_row99_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ee78a_row0_col2, #T_ee78a_row35_col3, #T_ee78a_row59_col2, #T_ee78a_row77_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ee78a_row0_col3, #T_ee78a_row2_col2, #T_ee78a_row59_col3, #T_ee78a_row77_col3, #T_ee78a_row89_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ee78a_row0_col4, #T_ee78a_row15_col4, #T_ee78a_row23_col1, #T_ee78a_row27_col5, #T_ee78a_row29_col5, #T_ee78a_row48_col1, #T_ee78a_row48_col4, #T_ee78a_row50_col1, #T_ee78a_row56_col1, #T_ee78a_row58_col1, #T_ee78a_row61_col5, #T_ee78a_row63_col1, #T_ee78a_row64_col4, #T_ee78a_row65_col1, #T_ee78a_row66_col5, #T_ee78a_row83_col5, #T_ee78a_row88_col5, #T_ee78a_row89_col4, #T_ee78a_row94_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ee78a_row0_col6, #T_ee78a_row19_col3, #T_ee78a_row20_col3, #T_ee78a_row30_col3, #T_ee78a_row36_col3, #T_ee78a_row51_col2, #T_ee78a_row53_col2, #T_ee78a_row56_col3, #T_ee78a_row63_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ee78a_row1_col0, #T_ee78a_row16_col2, #T_ee78a_row29_col6, #T_ee78a_row50_col0, #T_ee78a_row89_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ee78a_row1_col2, #T_ee78a_row2_col3, #T_ee78a_row12_col0, #T_ee78a_row50_col2, #T_ee78a_row57_col2, #T_ee78a_row81_col6, #T_ee78a_row97_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ee78a_row1_col3, #T_ee78a_row7_col3, #T_ee78a_row12_col2, #T_ee78a_row16_col3, #T_ee78a_row38_col6, #T_ee78a_row44_col2, #T_ee78a_row64_col0, #T_ee78a_row70_col6, #T_ee78a_row80_col6, #T_ee78a_row97_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ee78a_row1_col4, #T_ee78a_row5_col5, #T_ee78a_row8_col5, #T_ee78a_row12_col5, #T_ee78a_row13_col4, #T_ee78a_row14_col5, #T_ee78a_row16_col1, #T_ee78a_row16_col4, #T_ee78a_row26_col1, #T_ee78a_row33_col4, #T_ee78a_row35_col5, #T_ee78a_row44_col1, #T_ee78a_row47_col5, #T_ee78a_row51_col5, #T_ee78a_row53_col1, #T_ee78a_row59_col1, #T_ee78a_row64_col5, #T_ee78a_row77_col5, #T_ee78a_row91_col5, #T_ee78a_row99_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ee78a_row1_col6, #T_ee78a_row31_col0, #T_ee78a_row98_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ee78a_row2_col0, #T_ee78a_row5_col3, #T_ee78a_row16_col0, #T_ee78a_row31_col3, #T_ee78a_row89_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ee78a_row2_col1, #T_ee78a_row2_col5, #T_ee78a_row8_col4, #T_ee78a_row18_col4, #T_ee78a_row20_col4, #T_ee78a_row23_col5, #T_ee78a_row29_col4, #T_ee78a_row31_col4, #T_ee78a_row41_col1, #T_ee78a_row43_col1, #T_ee78a_row43_col4, #T_ee78a_row43_col5, #T_ee78a_row45_col4, #T_ee78a_row47_col1, #T_ee78a_row56_col5, #T_ee78a_row58_col5, #T_ee78a_row59_col4, #T_ee78a_row63_col5, #T_ee78a_row65_col5, #T_ee78a_row73_col1, #T_ee78a_row75_col4, #T_ee78a_row81_col5, #T_ee78a_row84_col1, #T_ee78a_row84_col4, #T_ee78a_row85_col6, #T_ee78a_row87_col4, #T_ee78a_row88_col4, #T_ee78a_row91_col1, #T_ee78a_row97_col1, #T_ee78a_row97_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ee78a_row2_col4, #T_ee78a_row4_col4, #T_ee78a_row13_col1, #T_ee78a_row13_col5, #T_ee78a_row25_col4, #T_ee78a_row27_col1, #T_ee78a_row29_col1, #T_ee78a_row36_col4, #T_ee78a_row38_col4, #T_ee78a_row38_col5, #T_ee78a_row53_col4, #T_ee78a_row54_col4, #T_ee78a_row57_col4, #T_ee78a_row61_col1, #T_ee78a_row66_col1, #T_ee78a_row68_col1, #T_ee78a_row68_col5, #T_ee78a_row73_col4, #T_ee78a_row81_col1, #T_ee78a_row83_col1, #T_ee78a_row88_col1, #T_ee78a_row94_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col0, #T_ee78a_row25_col0, #T_ee78a_row34_col4, #T_ee78a_row95_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col1, #T_ee78a_row8_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col2, #T_ee78a_row10_col5, #T_ee78a_row25_col2, #T_ee78a_row56_col4, #T_ee78a_row80_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col3, #T_ee78a_row10_col1, #T_ee78a_row25_col3, #T_ee78a_row80_col1, #T_ee78a_row95_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col4, #T_ee78a_row17_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ee78a_row3_col6, #T_ee78a_row22_col0, #T_ee78a_row73_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ee78a_row4_col0, #T_ee78a_row36_col0, #T_ee78a_row45_col6, #T_ee78a_row54_col3, #T_ee78a_row58_col3, #T_ee78a_row99_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ee78a_row4_col1, #T_ee78a_row42_col4, #T_ee78a_row49_col4, #T_ee78a_row54_col1, #T_ee78a_row54_col5, #T_ee78a_row61_col4, #T_ee78a_row62_col1, #T_ee78a_row68_col4, #T_ee78a_row85_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ee78a_row4_col2, #T_ee78a_row19_col0, #T_ee78a_row20_col0, #T_ee78a_row30_col0, #T_ee78a_row36_col2, #T_ee78a_row56_col2, #T_ee78a_row60_col6, #T_ee78a_row85_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_ee78a_row4_col3, #T_ee78a_row15_col2, #T_ee78a_row30_col2, #T_ee78a_row48_col6, #T_ee78a_row51_col0, #T_ee78a_row53_col0, #T_ee78a_row85_col3, #T_ee78a_row98_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ee78a_row4_col5, #T_ee78a_row22_col1, #T_ee78a_row37_col1, #T_ee78a_row37_col5, #T_ee78a_row55_col1, #T_ee78a_row62_col5, #T_ee78a_row65_col4, #T_ee78a_row78_col1, #T_ee78a_row85_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ee78a_row4_col6, #T_ee78a_row22_col2, #T_ee78a_row37_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ee78a_row5_col0, #T_ee78a_row31_col2, #T_ee78a_row35_col2, #T_ee78a_row59_col0, #T_ee78a_row75_col3, #T_ee78a_row77_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ee78a_row5_col4, #T_ee78a_row6_col4, #T_ee78a_row7_col5, #T_ee78a_row12_col4, #T_ee78a_row35_col4, #T_ee78a_row38_col1, #T_ee78a_row72_col1, #T_ee78a_row72_col4, #T_ee78a_row76_col5, #T_ee78a_row79_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ee78a_row5_col6, #T_ee78a_row37_col3, #T_ee78a_row88_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ee78a_row6_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_ee78a_row6_col1, #T_ee78a_row62_col4, #T_ee78a_row71_col1, #T_ee78a_row90_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ee78a_row6_col2, #T_ee78a_row23_col3, #T_ee78a_row46_col6, #T_ee78a_row74_col6, #T_ee78a_row93_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ee78a_row6_col3, #T_ee78a_row76_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ee78a_row6_col5, #T_ee78a_row50_col4, #T_ee78a_row86_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_ee78a_row6_col6 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_ee78a_row7_col0, #T_ee78a_row7_col2, #T_ee78a_row41_col6, #T_ee78a_row44_col0, #T_ee78a_row50_col3, #T_ee78a_row51_col6, #T_ee78a_row65_col0, #T_ee78a_row65_col2, #T_ee78a_row94_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ee78a_row7_col1, #T_ee78a_row18_col5, #T_ee78a_row30_col4, #T_ee78a_row32_col6, #T_ee78a_row33_col5, #T_ee78a_row34_col5, #T_ee78a_row37_col6, #T_ee78a_row41_col4, #T_ee78a_row70_col4, #T_ee78a_row70_col5, #T_ee78a_row79_col1, #T_ee78a_r

# %% [markdown]
# ### Total Volatility Score

# %%
original_df = volatility_df.copy()
normalized_df = volatility_df.copy()

scaler = MinMaxScaler()

# Extract the skewness column and multiply by -1 before normalization
skewness_column = 'Skewness (Lower = More Volatile)'
normalized_df[skewness_column] = -normalized_df[skewness_column]

# Normalize the metrics
normalized_df = pd.DataFrame(scaler.fit_transform(normalized_df), columns=normalized_df.columns, index=normalized_df.index)

# Add a column with the total score by summing the normalized values
normalized_df['Total Volatility Score'] = normalized_df.sum(axis=1)

sorted_normalized_df = normalized_df.sort_values(by='Total Volatility Score', ascending=False)

# Get the order of the rows after sorting
sorted_index = sorted_normalized_df.index

# Reorder the original dataframe based on the sorted index
sorted_original_df = original_df.loc[sorted_index]

sorted_original_df['Total Volatility Score'] = sorted_normalized_df['Total Volatility Score']

styled_df = sorted_original_df.style.background_gradient(cmap="coolwarm", axis=0)

styled_df
# Out:
# <style type="text/css">
# #T_44af4_row0_col0, #T_44af4_row66_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_44af4_row0_col1, #T_44af4_row0_col4, #T_44af4_row0_col5, #T_44af4_row0_col7, #T_44af4_row1_col0, #T_44af4_row1_col2, #T_44af4_row1_col3, #T_44af4_row13_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_44af4_row0_col2, #T_44af4_row26_col2, #T_44af4_row28_col2, #T_44af4_row29_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_44af4_row0_col3, #T_44af4_row30_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_44af4_row0_col6, #T_44af4_row45_col4, #T_44af4_row79_col4, #T_44af4_row95_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_44af4_row1_col1, #T_44af4_row12_col1, #T_44af4_row14_col1, #T_44af4_row94_col3, #T_44af4_row95_col3, #T_44af4_row96_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_44af4_row1_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_44af4_row1_col5, #T_44af4_row57_col4, #T_44af4_row94_col0, #T_44af4_row95_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_44af4_row1_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_44af4_row1_col7 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_44af4_row2_col0 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_44af4_row2_col1, #T_44af4_row54_col6, #T_44af4_row81_col6, #T_44af4_row96_col2, #T_44af4_row96_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_44af4_row2_col2, #T_44af4_row4_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_44af4_row2_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_44af4_row2_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_44af4_row2_col5, #T_44af4_row4_col5, #T_44af4_row16_col6, #T_44af4_row29_col6, #T_44af4_row96_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_44af4_row2_col6, #T_44af4_row20_col0, #T_44af4_row23_col0, #T_44af4_row23_col2, #T_44af4_row24_col0, #T_44af4_row25_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_44af4_row2_col7, #T_44af4_row7_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_44af4_row3_col0 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_44af4_row3_col1, #T_44af4_row61_col6, #T_44af4_row96_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_44af4_row3_col2, #T_44af4_row4_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_44af4_row3_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_44af4_row3_col4, #T_44af4_row97_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_44af4_row3_col5, #T_44af4_row4_col4, #T_44af4_row6_col4, #T_44af4_row7_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_44af4_row3_col6, #T_44af4_row6_col6, #T_44af4_row10_col6, #T_44af4_row15_col7, #T_44af4_row36_col2, #T_44af4_row72_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_44af4_row3_col7, #T_44af4_row11_col0, #T_44af4_row11_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_44af4_row4_col1, #T_44af4_row94_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_44af4_row4_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_44af4_row4_col6, #T_44af4_row18_col3, #T_44af4_row19_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_44af4_row4_col7 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_44af4_row5_col0 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_44af4_row5_col1, #T_44af4_row91_col2, #T_44af4_row93_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_44af4_row5_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_44af4_row5_col3 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_44af4_row5_col4, #T_44af4_row9_col5, #T_44af4_row14_col4, #T_44af4_row38_col4, #T_44af4_row39_col4, #T_44af4_row43_col4, #T_44af4_row62_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_44af4_row5_col5, #T_44af4_row8_col4, #T_44af4_row44_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_44af4_row5_col6, #T_44af4_row15_col6, #T_44af4_row16_col3, #T_44af4_row17_col0, #T_44af4_row21_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_44af4_row5_col7 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_44af4_row6_col0, #T_44af4_row6_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_44af4_row6_col1, #T_44af4_row40_col6, #T_44af4_row51_col6, #T_44af4_row87_col6, #T_44af4_row92_col7, #T_44af4_row93_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_44af4_row6_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_44af4_row6_col5, #T_44af4_row91_col3, #T_44af4_row93_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_44af4_row6_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_44af4_row7_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_44af4_row7_col1, #T_44af4_row8_col1, #T_44af4_row8_col5, #T_44af4_row49_col6, #T_44af4_row77_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_44af4_row7_col3, #T_44af4_row9_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_44af4_row7_col4, #T_44af4_row10_col5, #T_44af4_row31_col4, #T_44af4_row52_col6, #T_44af4_row74_col6, #T_44af4_row94_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_44af4_row7_col6, #T_44af4_row26_col0, #T_44af4_row28_col0, #T_44af4_row29_col0, #T_44af4_row31_col2, #T_44af4_row35_col2, #T_44af4_row37_col3, #T_44af4_row66_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_44af4_row7_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_44af4_row8_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_44af4_row8_col2 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_44af4_row8_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_44af4_row8_col6, #T_44af4_row14_col0 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_44af4_row8_col7, #T_44af4_row15_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_44af4_row9_col1, #T_44af4_row19_col4, #T_44af4_row21_col1, #T_44af4_row97_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_44af4_row9_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_44af4_row9_col3 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_44af4_row9_col4, #T_44af4_row10_col1, #T_44af4_row64_col6, #T_44af4_row93_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_44af4_row9_col6, #T_44af4_row17_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_44af4_row9_col7, #T_44af4_row14_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_44af4_row10_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_44af4_row10_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_44af4_row10_col3 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_44af4_row10_col4, #T_44af4_row11_col4, #T_44af4_row15_col1, #T_44af4_row18_col1, #T_44af4_row18_col5, #T_44af4_row20_col4, #T_44af4_row20_col5, #T_44af4_row25_col5, #T_44af4_row45_col5, #T_44af4_row57_col1, #T_44af4_row59_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_44af4_row10_col7, #T_44af4_row11_col6 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_44af4_row11_col1, #T_44af4_row17_col1, #T_44af4_row17_col5, #T_44af4_row23_col5, #T_44af4_row27_col4, #T_44af4_row97_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_44af4_row11_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_44af4_row11_col5, #T_44af4_row12_col4, #T_44af4_row19_col1, #T_44af4_row25_col1, #T_44af4_row26_col1, #T_44af4_row28_col1, #T_44af4_row30_col5, #T_44af4_row32_col1, #T_44af4_row32_col4, #T_44af4_row33_col1, #T_44af4_row37_col1, #T_44af4_row60_col4, #T_44af4_row72_col4, #T_44af4_row76_col4, #T_44af4_row98_col0, #T_44af4_row98_col2, #T_44af4_row98_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_44af4_row11_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_44af4_row12_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_44af4_row12_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_44af4_row12_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_44af4_row12_col5, #T_44af4_row14_col5, #T_44af4_row88_col4, #T_44af4_row94_col2, #T_4
